# %% [markdown]
# <a href="https://colab.research.google.com/github/S10958018/lichen/blob/master/Assessments_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("rJava")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("jiebaR")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘jiebaRD’

# %%
install.packages("tmcn")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("dplyr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("lubridate")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("stringr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("wordcloud")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("Rwordseg", repos="http://R-Forg.R-project.org")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “unable to access index for repository http://R-Forg.R-project.org/src/contrib:
#   cannot open URL 'http://R-Forg.R-project.org/src/contrib/PACKAGES'”
# Warning message:
# “package ‘Rwordseg’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”

# %%
library(dplyr)
library(lubridate)
library(stringr)
library(jiebaR)
library(wordcloud) #非互動式文字雲
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union
#
#
# Loading required package: jiebaRD
#
# Loading required package: RColorBrewer

# %%
content <- "法國總理：歐洲不能接收所有難民。德國與土耳其的內閣星期五（1月22日）於柏林會晤。與此同時，法國瓦爾斯表示歐洲不能接收所有敘利亞和伊拉克的難民。瓦爾斯在瑞士出席達沃斯論壇期間接受BBC首席國際事務記者杜薩採訪。他警告說移民危機正嚴重威脅歐盟。「歐洲不能收留所有從敘利亞和伊拉克逃出來的人，否則將完全破壞我們社會的穩定。」去年抵達歐洲的逃難者超過100萬人，他們大部分經海路到達希臘或意大利。星期五，有至少21人在希臘島嶼對開海域因船隻翻沉喪命。法國總理瓦爾斯重申，法國將維持緊急狀態直至殲滅「伊斯蘭國」IS組織的全球戰爭結束為止。去年11月巴黎遭受連環攻擊之後，法國宣佈進入緊急狀態，之後延長三個月。瓦爾斯對BBC記者杜薩表示，歐洲需要就控制對外邊境上緊急行動。「假若歐洲無法控制我們的邊界，歐洲這個概念根本無法成立。」瓦爾斯說移民危機令歐洲人口面對重大變化。他認為德國總理默克爾去年歡迎逃難者的信息是勇氣的表現，但那是錯誤的。他擔心逃難者湧進歐洲的情況，威脅著申根地區內的免護照自由流動。另一方面，德國和土耳其的總理星期五在柏林會面，討論星期二（19日）在伊斯坦布爾發生的襲擊，事件中十名德國人死亡。默克爾和達武特奧盧的內閣將討論攻擊善後工作、歐洲難民危機和恐怖主義問題。歐盟國家希望土耳其協助控制進入歐洲的逃難者，從敘利亞和其他衝突地區到歐盟的人，大多數先在土耳其落腳。目前有超過240萬逃難者滯留在土耳其。"

# %%
cutter <- worker(bylines = F)

# %%
cutter[content]
# Out:
#   [1] "法國總理"   "歐洲"       "不能"       "接收"       "所有"
#   [6] "難民"       "德國"       "與"         "土耳其"     "的"
#  [11] "內閣"       "星期五"     "1"          "月"         "22"
#  [16] "日"         "於柏林"     "會晤"       "與此同時"   "法國"
#  [21] "瓦爾斯"     "表示"       "歐洲"       "不能"       "接收"
#  [26] "所有"       "敘利亞"     "和"         "伊拉克"     "的"
#  [31] "難民"       "瓦爾斯"     "在"         "瑞士"       "出席"
#  [36] "達沃斯"     "論壇"       "期間"       "接受"       "BBC"
#  [41] "首席"       "國際事務"   "記者"       "杜薩"       "採訪"
#  [46] "他"         "警告"       "說"         "移民"       "危機"
#  [51] "正"         "嚴重威脅"   "歐盟"       "歐洲"       "不能"
#  [56] "收留"       "所有"       "從"         "敘利亞"     "和"
#  [61] "伊拉克"     "逃出來"     "的"         "人"         "否則"
#  [66] "將"         "完全"       "破壞"       "我們"       "社會"
#  [71] "的"         "穩定"       "去年"       "抵達"       "歐洲"
#  [76] "的"         "逃難"       "者"         "超過"       "100"
#  [81] "萬人"       "他們"       "大部分"     "經"         "海路"
# ...

# %%
new_words <- c("法國","歐洲","敘利亞","難民")

for (i in 1:length(new_words)) {
  new_user_word(cutter, new_words[i])
}

# %%
content <- str_remove_all(content, "[0-9a-zA-Z]+?")
cutter[content]
# Out:
#   [1] "法國"       "總理"       "歐洲"       "不能"       "接收"
#   [6] "所有"       "難民"       "德國"       "與"         "土耳其"
#  [11] "的"         "內閣"       "星期五"     "月"         "日"
#  [16] "於柏林"     "會晤"       "與此同時"   "法國"       "瓦爾斯"
#  [21] "表示"       "歐洲"       "不能"       "接收"       "所有"
#  [26] "敘利亞"     "和"         "伊拉克"     "的"         "難民"
#  [31] "瓦爾斯"     "在"         "瑞士"       "出席"       "達沃斯"
#  [36] "論壇"       "期間"       "接受"       "首席"       "國際事務"
#  [41] "記者"       "杜薩"       "採訪"       "他"         "警告"
#  [46] "說"         "移民"       "危機"       "正"         "嚴重威脅"
#  [51] "歐盟"       "歐洲"       "不能"       "收留"       "所有"
#  [56] "從"         "敘利亞"     "和"         "伊拉克"     "逃出來"
#  [61] "的"         "人"         "否則"       "將"         "完全"
#  [66] "破壞"       "我們"       "社會"       "的"         "穩定"
#  [71] "去年"       "抵達"       "歐洲"       "的"         "逃難"
#  [76] "者"         "超過"       "萬人"       "他們"       "大部分"
#  [81] "經"         "海路"       "到達"       "希臘"       "或"
# ...

# %%
new_words <- c("法國","歐洲","敘利亞","難民")
writeLines(new_words, "new_words.txt")

# %%
stop_words <- c("在", "之", "更", "個", "未", "而", "也", "與", "的", "著", "和", "對", "就", "但", "那", "是", "日", "月", "他", "說", "從", "將", "有", "我們", "超過", "不能", "之後", "所有", "之後", "者", "人", "表示")
writeLines(stop_words, "stop_words.txt")

# %%
cutter <- worker(user = "new_words.txt", stop_word = "stop_words.txt", bylines = FALSE)
seg_words <- cutter[content]
seg_words
# Out:
#   [1] "法國"       "總理"       "歐洲"       "接收"       "難民"
#   [6] "德國"       "土耳其"     "內閣"       "星期五"     "於柏林"
#  [11] "會晤"       "與此同時"   "法國"       "瓦爾斯"     "歐洲"
#  [16] "接收"       "敘利亞"     "伊拉克"     "難民"       "瓦爾斯"
#  [21] "瑞士"       "出席"       "達沃斯"     "論壇"       "期間"
#  [26] "接受"       "首席"       "國際事務"   "記者"       "杜薩"
#  [31] "採訪"       "警告"       "移民"       "危機"       "正"
#  [36] "嚴重威脅"   "歐盟"       "歐洲"       "收留"       "敘利亞"
#  [41] "伊拉克"     "逃出來"     "否則"       "完全"       "破壞"
#  [46] "社會"       "穩定"       "去年"       "抵達"       "歐洲"
#  [51] "逃難"       "萬人"       "他們"       "大部分"     "經"
#  [56] "海路"       "到達"       "希臘"       "或"         "意大利"
#  [61] "星期五"     "至少"       "希臘"       "島嶼"       "對開"
#  [66] "海域"       "因"         "船隻"       "翻沉"       "喪命"
#  [71] "法國"       "總理"       "瓦爾斯"     "重申"       "法國"
#  [76] "維持"       "緊急狀態"   "直至"       "殲滅"       "伊斯蘭"
#  [81] "國"         "組織"       "全球"       "戰爭"       "結束"
# ...

# %%
txt_freq <- freq(seg_words)

# %%
txt_freq <- arrange(txt_freq, desc(freq))

# %%
head(txt_freq)
# Out:
#   char   freq
# 1 歐洲   11
# 2 法國    5
# 3 土耳其  5
# 4 瓦爾斯  5
# 5 逃難    5
# 6 危機    3

# %%
par(family = ("Microsoft YaHei"))

# %%
wordcloud(txt_freq$char, txt_freq$freq, min.freq=2, random.order=F,
ordered.colors=F, colors=rainbow(nrow(txt_freq)))
# Out:
# plot without title

# %%
install.packages("showtext")
library(showtext)
showtext.auto(enable = TRUE)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
wordcloud(txt_freq$char, txt_freq$freq, min.freq=2, random.order=F,
ordered.colors=F, colors=rainbow(nrow(txt_freq)))
# Out:
# plot without title
